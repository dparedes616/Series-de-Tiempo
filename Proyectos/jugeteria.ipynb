# %% [markdown]
# # Proyecto de ETE pata Jugeteria

# %% [markdown]
# ### Librerias

# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# %% [markdown]
# ### Data

# %%
df_jugeteria = pd.read_csv("/home/daniel/Drive WLS/Cursos/machine-learning/series_de_tiempo/Data/juguetes.csv", index_col="mes")
df_jugeteria.head()
# Out:
#          ventas
# mes
# 2019-01     714
# 2019-02     841
# 2019-03    1100
# 2019-04    1098
# 2019-05    1107

# %% [markdown]
# ### Tranformación

# %%
df_jugeteria.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60 entries, 2019-01 to 2023-12
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ventas  60 non-null     int64
# dtypes: int64(1)
# memory usage: 960.0+ bytes

# %%
df_jugeteria.isnull().sum()
# Out:
# ventas    0
# dtype: int64

# %%
df_jugeteria.index=pd.to_datetime(df_jugeteria.index)

# %%
df_jugeteria.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 60 entries, 2019-01-01 to 2023-12-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ventas  60 non-null     int64
# dtypes: int64(1)
# memory usage: 960.0 bytes

# %%
df_jugeteria.head()
# Out:
#             ventas
# mes
# 2019-01-01     714
# 2019-02-01     841
# 2019-03-01    1100
# 2019-04-01    1098
# 2019-05-01    1107

# %% [markdown]
# ### Analisis ETE

# %%
grafico_ventas = plt.figure()
ax = grafico_ventas.add_axes([0,0,1,1])
ax.plot(df_jugeteria["ventas"], label="Ventas")
ax.set_title("Inversión real en EEUU entre 2019-01 a 2023-12")
ax.set_xlabel("Año-Mes")
ax.set_ylabel("Miles de millones USD")
ax.legend(loc='best') 
ax.grid(True)
plt.show()

# %%
grafico_ventas.savefig("Grafico de ventas.png", dpi=600 , bbox_inches="tight")

# %% [markdown]
# #### Analisis Adtitivo

# %%
ete_aditive = seasonal_decompose(df_jugeteria["ventas"], model="aditive")
ete_aditive

# %%
grafico_aditivo = ete_aditive.plot()

# %% [markdown]
# #### Analisis Multiplicativo

# %%
ete_multiplicative = seasonal_decompose(df_jugeteria["ventas"], model="multiplicative")
ete_multiplicative

# %%
grafico_multiplicativo = ete_multiplicative.plot()

# %%
grafico_multiplicativo.savefig("Grafico de descomposición.png", dpi=600 , bbox_inches="tight")
