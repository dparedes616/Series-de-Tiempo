# %% [markdown]
# ## StatasModel

# %% [markdown]
# ### Librerias

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %% [markdown]
# ### Data

# %%
datosmacro = sm.datasets.macrodata.load_pandas().data

# %%
datosmacro
# Out:
#        year  quarter    realgdp  realcons   realinv  realgovt  realdpi  \
# 0    1959.0      1.0   2710.349    1707.4   286.898   470.045   1886.9
# 1    1959.0      2.0   2778.801    1733.7   310.859   481.301   1919.7
# 2    1959.0      3.0   2775.488    1751.8   289.226   491.260   1916.4
# 3    1959.0      4.0   2785.204    1753.7   299.356   484.052   1931.3
# 4    1960.0      1.0   2847.699    1770.5   331.722   462.199   1955.5
# ..      ...      ...        ...       ...       ...       ...      ...
# 198  2008.0      3.0  13324.600    9267.7  1990.693   991.551   9838.3
# 199  2008.0      4.0  13141.920    9195.3  1857.661  1007.273   9920.4
# 200  2009.0      1.0  12925.410    9209.2  1558.494   996.287   9926.4
# 201  2009.0      2.0  12901.504    9189.0  1456.678  1023.528  10077.5
# 202  2009.0      3.0  12990.341    9256.0  1486.398  1044.088  10040.6
#
#          cpi      m1  tbilrate  unemp      pop  infl  realint
# ...

# %%
print(sm.datasets.macrodata.NOTE)
# Out:
# ::
#     Number of Observations - 203
#
#     Number of Variables - 14
#
#     Variable name definitions::
#
#         year      - 1959q1 - 2009q3
#         quarter   - 1-4
#         realgdp   - Real gross domestic product (Bil. of chained 2005 US$,
#                     seasonally adjusted annual rate)
#         realcons  - Real personal consumption expenditures (Bil. of chained
#                     2005 US$, seasonally adjusted annual rate)
#         realinv   - Real gross private domestic investment (Bil. of chained
#                     2005 US$, seasonally adjusted annual rate)
#         realgovt  - Real federal consumption expenditures & gross investment
#                     (Bil. of chained 2005 US$, seasonally adjusted annual rate)
#         realdpi   - Real private disposable income (Bil. of chained 2005
#                     US$, seasonally adjusted annual rate)
#         cpi       - End of the quarter consumer price index for all urban
# ...

# %%
indice = pd.Index(sm.tsa.datetools.dates_from_range("1959Q1", "2009Q3"))

# %%
datosmacro.index = indice

# %%
datosmacro.head()
# Out:
#               year  quarter   realgdp  realcons  realinv  realgovt  realdpi  \
# 1959-03-31  1959.0      1.0  2710.349    1707.4  286.898   470.045   1886.9
# 1959-06-30  1959.0      2.0  2778.801    1733.7  310.859   481.301   1919.7
# 1959-09-30  1959.0      3.0  2775.488    1751.8  289.226   491.260   1916.4
# 1959-12-31  1959.0      4.0  2785.204    1753.7  299.356   484.052   1931.3
# 1960-03-31  1960.0      1.0  2847.699    1770.5  331.722   462.199   1955.5
#
#               cpi     m1  tbilrate  unemp      pop  infl  realint
# 1959-03-31  28.98  139.7      2.82    5.8  177.146  0.00     0.00
# 1959-06-30  29.15  141.7      3.08    5.1  177.830  2.34     0.74
# 1959-09-30  29.35  140.5      3.82    5.3  178.657  2.74     1.09
# 1959-12-31  29.37  140.0      4.33    5.6  179.386  0.27     4.06
# 1960-03-31  29.54  139.6      3.50    5.2  180.007  2.31     1.19

# %% [markdown]
# ## Serie temporal de gastos por trimestre en los Estado Unidos

# %%
data = datosmacro
data.head()
# Out:
#               year  quarter   realgdp  realcons  realinv  realgovt  realdpi  \
# 1959-03-31  1959.0      1.0  2710.349    1707.4  286.898   470.045   1886.9
# 1959-06-30  1959.0      2.0  2778.801    1733.7  310.859   481.301   1919.7
# 1959-09-30  1959.0      3.0  2775.488    1751.8  289.226   491.260   1916.4
# 1959-12-31  1959.0      4.0  2785.204    1753.7  299.356   484.052   1931.3
# 1960-03-31  1960.0      1.0  2847.699    1770.5  331.722   462.199   1955.5
#
#               cpi     m1  tbilrate  unemp      pop  infl  realint
# 1959-03-31  28.98  139.7      2.82    5.8  177.146  0.00     0.00
# 1959-06-30  29.15  141.7      3.08    5.1  177.830  2.34     0.74
# 1959-09-30  29.35  140.5      3.82    5.3  178.657  2.74     1.09
# 1959-12-31  29.37  140.0      4.33    5.6  179.386  0.27     4.06
# 1960-03-31  29.54  139.6      3.50    5.2  180.007  2.31     1.19

# %%
grafico_1 = plt.figure(figsize=(10,5), dpi=300)
axe = grafico_1.add_axes([0,0,1,1])
axe= plt.plot(data["realcons"])
axe = plt.title("Gasto de consumo real en EEUU entre 1959-2009")
axe = plt.xlabel("Año-Trimestre")
axe = plt.ylabel("Gasto real en miles de millones USD")
axe =plt.grid(True)
plt.show()

# %% [markdown]
# ## Serie temporal de inversión real por trimestre en los Estado Unidos

# %%
grafico_2 = plt.figure(figsize=(10,5), dpi=300)
axe = grafico_2.add_axes([0,0,1,1])
axe= plt.plot(data["realinv"])
axe = plt.title("Gasto de consumo real en EEUU entre 1959-2009")
axe = plt.xlabel("Año-Trimestre")
axe = plt.ylabel("Gasto real en miles de millones USD")
axe =plt.grid(True)
plt.show()

# %% [markdown]
# ### Filtro Hodrick-Prescoot

# %% [markdown]
# Metodo para extraer la tendencia de la serie de tiempo

# %% [markdown]
# ### Tencia de la inversión real

# %%
filtrohp=sm.tsa.filters.hpfilter(data["realinv"])
type(filtrohp)
# Out:
# tuple

# %%
realiv_ciclo, relinv_tendencia = sm.tsa.filters.hpfilter(data["realinv"]) #descomponer la tendencia

# %%
data["tendencia"] = relinv_tendencia
data.head()
# Out:
#               year  quarter   realgdp  realcons  realinv  realgovt  realdpi  \
# 1959-03-31  1959.0      1.0  2710.349    1707.4  286.898   470.045   1886.9
# 1959-06-30  1959.0      2.0  2778.801    1733.7  310.859   481.301   1919.7
# 1959-09-30  1959.0      3.0  2775.488    1751.8  289.226   491.260   1916.4
# 1959-12-31  1959.0      4.0  2785.204    1753.7  299.356   484.052   1931.3
# 1960-03-31  1960.0      1.0  2847.699    1770.5  331.722   462.199   1955.5
#
#               cpi     m1  tbilrate  unemp      pop  infl  realint   tendencia
# 1959-03-31  28.98  139.7      2.82    5.8  177.146  0.00     0.00  277.366741
# 1959-06-30  29.15  141.7      3.08    5.1  177.830  2.34     0.74  280.828920
# 1959-09-30  29.35  140.5      3.82    5.3  178.657  2.74     1.09  284.297056
# 1959-12-31  29.37  140.0      4.33    5.6  179.386  0.27     4.06  287.795875
# 1960-03-31  29.54  139.6      3.50    5.2  180.007  2.31     1.19  291.353183

# %%
grafico_3 = plt.figure(figsize=(5,5), dpi=150)
ax = grafico_3.add_axes([0,0,1,1])
ax.plot(data["realinv"], label="Inversión Real")
ax.plot(data["tendencia"], label="Tendencia de Inversión")
ax.set_title("Inversión real en EEUU entre 1959-2009")
ax.set_xlabel("Año-Trimestre")
ax.set_ylabel("Miles de millones USD")
ax.legend(loc='best') 
ax.grid(True)
plt.show()

# %%
data[["realinv","tendencia"]]["1990-01-31":].plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Tencia del gasto real

# %%
data.head()
# Out:
#               year  quarter   realgdp  realcons  realinv  realgovt  realdpi  \
# 1959-03-31  1959.0      1.0  2710.349    1707.4  286.898   470.045   1886.9
# 1959-06-30  1959.0      2.0  2778.801    1733.7  310.859   481.301   1919.7
# 1959-09-30  1959.0      3.0  2775.488    1751.8  289.226   491.260   1916.4
# 1959-12-31  1959.0      4.0  2785.204    1753.7  299.356   484.052   1931.3
# 1960-03-31  1960.0      1.0  2847.699    1770.5  331.722   462.199   1955.5
#
#               cpi     m1  tbilrate  unemp      pop  infl  realint   tendencia
# 1959-03-31  28.98  139.7      2.82    5.8  177.146  0.00     0.00  277.366741
# 1959-06-30  29.15  141.7      3.08    5.1  177.830  2.34     0.74  280.828920
# 1959-09-30  29.35  140.5      3.82    5.3  178.657  2.74     1.09  284.297056
# 1959-12-31  29.37  140.0      4.33    5.6  179.386  0.27     4.06  287.795875
# 1960-03-31  29.54  139.6      3.50    5.2  180.007  2.31     1.19  291.353183

# %%
filtrohp=sm.tsa.filters.hpfilter(data["realcons"])
type(filtrohp)
# Out:
# tuple

# %%
realiv_ciclo_cons, relinv_tendencia = filtrohp
data["tendencia_cons"] = relinv_tendencia
data.head()
# Out:
#               year  quarter   realgdp  realcons  realinv  realgovt  realdpi  \
# 1959-03-31  1959.0      1.0  2710.349    1707.4  286.898   470.045   1886.9
# 1959-06-30  1959.0      2.0  2778.801    1733.7  310.859   481.301   1919.7
# 1959-09-30  1959.0      3.0  2775.488    1751.8  289.226   491.260   1916.4
# 1959-12-31  1959.0      4.0  2785.204    1753.7  299.356   484.052   1931.3
# 1960-03-31  1960.0      1.0  2847.699    1770.5  331.722   462.199   1955.5
#
#               cpi     m1  tbilrate  unemp      pop  infl  realint   tendencia  \
# 1959-03-31  28.98  139.7      2.82    5.8  177.146  0.00     0.00  277.366741
# 1959-06-30  29.15  141.7      3.08    5.1  177.830  2.34     0.74  280.828920
# 1959-09-30  29.35  140.5      3.82    5.3  178.657  2.74     1.09  284.297056
# 1959-12-31  29.37  140.0      4.33    5.6  179.386  0.27     4.06  287.795875
# 1960-03-31  29.54  139.6      3.50    5.2  180.007  2.31     1.19  291.353183
#
#             tendencia_cons
# ...

# %%
grafico_4 = plt.figure(figsize=(5,5), dpi=150)
ax = grafico_4.add_axes([0,0,1,1])
ax.plot(data["realcons"], label="Gasto Real")
ax.plot(data["tendencia_cons"], label="Tendencia del Gaso Real")
ax.set_title("Gasrto real en EEUU entre 1959-2009")
ax.set_xlabel("Año-Trimestre")
ax.set_ylabel("Miles de millones USD")
ax.legend(loc='best') 
ax.grid(True)
plt.show()

# %% [markdown]
# ### Componente Ciclico del Gasto Real

# %% [markdown]
# El componente ciclico en el contexto de analisis de series de tiempo se refiere a las fluctuaciones o patrones que se rfepetin en los datos a lo largo del tiempo, pero que no siguen una tencia constante hascia arriba o hacia a bajo.

# %% [markdown]
# #### Grafico de componente ciclico

# %%
grafico_5 = plt.figure(figsize=(5,5), dpi=150)
ax = grafico_5.add_axes([0,0,1,1])
ax.plot(realiv_ciclo_cons)
ax.set_title("Componente ciclico del gasto real en EEUU entre 1959-2009")
ax.set_xlabel("Año-Trimestre")
ax.set_ylabel("Miles de millones USD")
ax.grid(True)
plt.show()
